# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
from scipy import stats

df_vaccination_raw = pd.read_csv('data/country_vaccinations.csv')
df_population_raw = pd.read_csv('data/population_by_country_2020.csv')

# %%
df_vaccination_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11364 entries, 0 to 11363
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              11364 non-null  object
#  1   iso_code                             11364 non-null  object
#  2   date                                 11364 non-null  object
#  3   total_vaccinations                   6756 non-null   float64
#  4   people_vaccinated                    6091 non-null   float64
#  5   people_fully_vaccinated              4362 non-null   float64
#  6   daily_vaccinations_raw               5646 non-null   float64
#  7   daily_vaccinations                   11167 non-null  float64
#  8   total_vaccinations_per_hundred       6756 non-null   float64
#  9   people_vaccinated_per_hundred        6091 non-null   float64
#  10  people_fully_vaccinated_per_hundred  4362 non-null   float64
#  11  daily_vaccinations_per_million       11167 non-null  float64
#  12  vaccines                             11364 non-null  object
#  13  source_name                          11364 non-null  object
#  14  source_website                       11364 non-null  object
# dtypes: float64(9), object(6)
# memory usage: 1.3+ MB

# %%
df_vaccination = df_vaccination_raw[['country','people_vaccinated_per_hundred']]
df_vaccination
# Out:
#            country  people_vaccinated_per_hundred
# 0      Afghanistan                           0.00
# 1      Afghanistan                            NaN
# 2      Afghanistan                            NaN
# 3      Afghanistan                            NaN
# 4      Afghanistan                            NaN
# ...            ...                            ...
# 11359     Zimbabwe                           1.12
# 11360     Zimbabwe                           1.20
# 11361     Zimbabwe                           1.30
# 11362     Zimbabwe                           1.31
# 11363     Zimbabwe                           1.38
#
# [11364 rows x 2 columns]

# %%
df_vaccination.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei', 'Bulgaria', 'Cambodia', 'Canada',
#        'Cape Verde', 'Cayman Islands', 'Chile', 'China', 'Colombia',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Equatorial Guinea', 'Estonia',
#        'Eswatini', 'Faeroe Islands', 'Falkland Islands', 'Finland',
#        'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana',
#        'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guatemala',
#        'Guernsey', 'Guinea', 'Guyana', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland',
#        'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kosovo', 'Kuwait', 'Kyrgyzstan',
#        'Laos', 'Latvia', 'Lebanon', 'Liechtenstein', 'Lithuania',
#        'Luxembourg', 'Macao', 'Malawi', 'Malaysia', 'Maldives', 'Mali',
#        'Malta', 'Mauritania', 'Mauritius', 'Mexico', 'Moldova', 'Monaco',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nepal', 'Netherlands', 'New Zealand',
#        'Nigeria', 'North Macedonia', 'Northern Cyprus',
#        'Northern Ireland', 'Norway', 'Oman', 'Pakistan', 'Palestine',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Scotland', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia',
#        'Slovenia', 'Solomon Islands', 'South Africa', 'South Korea',
#        'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Sweden', 'Switzerland',
#        'Syria', 'Taiwan', 'Thailand', 'Togo', 'Trinidad and Tobago',
#        'Tunisia', 'Turkey', 'Turks and Caicos Islands', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan', 'Venezuela', 'Vietnam',
#        'Wales', 'Zimbabwe'], dtype=object)

# %%
# show the max total_vaccinations_per_hundred
vaccination_max_country = df_vaccination.groupby('country').max()
vaccination_max_country
# Out:
#              people_vaccinated_per_hundred
# country
# Afghanistan                           0.31
# Albania                               0.21
# Algeria                                NaN
# Andorra                               9.19
# Angola                                0.75
# ...                                    ...
# Uzbekistan                            0.44
# Venezuela                             0.88
# Vietnam                               0.06
# Wales                                50.36
# Zimbabwe                              1.38
#
# [176 rows x 1 columns]

# %%
vaccination_max_country.dropna()
# Out:
#              people_vaccinated_per_hundred
# country
# Afghanistan                           0.31
# Albania                               0.21
# Andorra                               9.19
# Angola                                0.75
# Anguilla                             38.89
# ...                                    ...
# Uzbekistan                            0.44
# Venezuela                             0.88
# Vietnam                               0.06
# Wales                                50.36
# Zimbabwe                              1.38
#
# [167 rows x 1 columns]

# %%
df_population_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (or dependency)  235 non-null    object
#  1   Population (2020)        235 non-null    int64
#  2   Yearly Change            235 non-null    object
#  3   Net Change               235 non-null    int64
#  4   Density (P/Km²)          235 non-null    int64
#  5   Land Area (Km²)          235 non-null    int64
#  6   Migrants (net)           201 non-null    float64
#  7   Fert. Rate               235 non-null    object
#  8   Med. Age                 235 non-null    object
#  9   Urban Pop %              235 non-null    object
#  10  World Share              235 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.3+ KB

# %%
df_population_raw.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# 2        83 %      4.25 %
# 3        56 %      3.51 %
# 4        35 %      2.83 %

# %%
df_population_raw.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
df_population = df_population_raw[['Country (or dependency)', 'Population (2020)']]

# %%
df_population.columns = ['country','population']
#df_population = df_population.population.astype(str)
df_population
# Out:
#               country  population
# 0               China  1440297825
# 1               India  1382345085
# 2       United States   331341050
# 3           Indonesia   274021604
# 4            Pakistan   221612785
# ..                ...         ...
# 230        Montserrat        4993
# 231  Falkland Islands        3497
# 232              Niue        1628
# 233           Tokelau        1360
# 234          Holy See         801
#
# [235 rows x 2 columns]

# %%
df_population.set_index('country', inplace=True)

# %%
df_population
# Out:
#                   population
# country
# China             1440297825
# India             1382345085
# United States      331341050
# Indonesia          274021604
# Pakistan           221612785
# ...                      ...
# Montserrat              4993
# Falkland Islands        3497
# Niue                    1628
# Tokelau                 1360
# Holy See                 801
#
# [235 rows x 1 columns]

# %%
df_population.index.unique()
# Out:
# Index(['China', 'India', 'United States', 'Indonesia', 'Pakistan', 'Brazil',
#        'Nigeria', 'Bangladesh', 'Russia', 'Mexico',
#        ...
#        'Wallis & Futuna', 'Nauru', 'Saint Barthelemy', 'Saint Helena',
#        'Saint Pierre & Miquelon', 'Montserrat', 'Falkland Islands', 'Niue',
#        'Tokelau', 'Holy See'],
#       dtype='object', name='country', length=235)

# %%
df_population['population'] = df_population['population'].astype(str)
# Out:
# <ipython-input-15-c3496bb546cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_population['population'] = df_population['population'].astype(str)

# %%
vac_pop = pd.merge(vaccination_max_country, df_population, left_index=True, right_index=True, how='left')

# %%
vac_pop.head()
# Out:
#              people_vaccinated_per_hundred population
# country
# Afghanistan                           0.31   39074280
# Albania                               0.21    2877239
# Algeria                                NaN   43984569
# Andorra                               9.19      77287
# Angola                                0.75   33032075

# %%
vac_pop.shape
# Out:
# (176, 2)

# %%
vac_pop.population.isnull()
# Out:
# country
# Afghanistan    False
# Albania        False
# Algeria        False
# Andorra        False
# Angola         False
#                ...
# Uzbekistan     False
# Venezuela      False
# Vietnam        False
# Wales           True
# Zimbabwe       False
# Name: population, Length: 176, dtype: bool

# %%
vac_pop[vac_pop.population.isnull()]
# Out:
#                                   people_vaccinated_per_hundred population
# country
# Cape Verde                                                 0.39        NaN
# Cote d'Ivoire                                              0.26        NaN
# Czechia                                                   13.13        NaN
# England                                                   48.16        NaN
# Guernsey                                                  44.11        NaN
# Jersey                                                    44.57        NaN
# Kosovo                                                     0.13        NaN
# Northern Cyprus                                           14.10        NaN
# Northern Ireland                                          43.64        NaN
# Palestine                                                  2.58        NaN
# Saint Kitts and Nevis                                     19.66        NaN
# Saint Vincent and the Grenadines                            NaN        NaN
# Sao Tome and Principe                                      4.44        NaN
# Scotland                                                  48.85        NaN
# Turks and Caicos Islands                                  33.41        NaN
# Wales                                                     50.36        NaN

# %%
vaccination_max_country.rename(index={'Czechia':'Czech Republic (Czechia)'}, inplace=True)

# %%
vaccination_max_country.loc['Czech Republic (Czechia)',:]
# Out:
# people_vaccinated_per_hundred    13.13
# Name: Czech Republic (Czechia), dtype: float64

# %%
vac_pop2 = pd.merge(vaccination_max_country, df_population, left_index=True, right_index=True, how='left')

# %%
vac_pop2.isnull().sum()
# Out:
# people_vaccinated_per_hundred     9
# population                       15
# dtype: int64

# %%
vac_pop3 = vac_pop2.dropna()

# %%
vac_pop3
# Out:
#              people_vaccinated_per_hundred population
# country
# Afghanistan                           0.31   39074280
# Albania                               0.21    2877239
# Andorra                               9.19      77287
# Angola                                0.75   33032075
# Anguilla                             38.89      15026
# ...                                    ...        ...
# Uruguay                              25.12    3475842
# Uzbekistan                            0.44   33551824
# Venezuela                             0.88   28421581
# Vietnam                               0.06   97490013
# Zimbabwe                              1.38   14899771
#
# [153 rows x 2 columns]

# %%
vac_pop3['population'] = vac_pop2.population.astype(float)
# Out:
# <ipython-input-27-29acfceb4e62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vac_pop3['population'] = vac_pop2.population.astype(float)

# %%
vac_pop3.head()
# Out:
#              people_vaccinated_per_hundred  population
# country
# Afghanistan                           0.31  39074280.0
# Albania                               0.21   2877239.0
# Andorra                               9.19     77287.0
# Angola                                0.75  33032075.0
# Anguilla                             38.89     15026.0

# %%
vac_pop3['people_vaccinated_per_hundred']
# Out:
# country
# Afghanistan     0.31
# Albania         0.21
# Andorra         9.19
# Angola          0.75
# Anguilla       38.89
#                ...
# Uruguay        25.12
# Uzbekistan      0.44
# Venezuela       0.88
# Vietnam         0.06
# Zimbabwe        1.38
# Name: people_vaccinated_per_hundred, Length: 153, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#df= pd.read_csv('population_by_hundred2.csv')
x = vac_pop3['population']
y = vac_pop3['people_vaccinated_per_hundred']


plt.xlabel("Population count")
plt.ylabel("percentage of population vaccinated")


slope, intercept, r, p, std_err = stats.linregress(x, y)


def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

print (mymodel)
plt.xticks(rotation=90)
plt.scatter(x,y)
plt.plot(x, mymodel)
# Out:
# [12.17028766700402, 12.55532091355469, 12.585104414607885, 12.234559489871383, 12.585766694018059, 12.584883353418663, 12.104410017874994, 12.554395694507505, 12.314140156436869, 12.490028807457286, 12.477906533889833, 12.581736630040705, 12.567725762932543, 10.831091409042019, 12.582869018163114, 12.485418550933257, 12.462552099379613, 12.581683954888696, 12.58526450367043, 12.577703279184924, 12.461469705848163, 12.56082727525453, 10.322107775119722, 12.581265308693707, 12.51211517319759, 12.407664452704248, 12.183848678527855, 12.585226029109684, 12.382282549899275, 12.043684683644628, 12.531654123059791, 12.54230657692729, 12.573067429685182, 12.471976292518674, 12.524275963874377, 12.585160472372644, 12.470336193369334, 12.397770299773008, 11.493926312306423, 12.516870988441344, 12.570923693536221, 12.571814299307027, 12.573563684504776, 12.58540641384873, 12.58588932968597, 12.526972938039481, 11.891332209590939, 12.56215837592029, 12.560101853739688, 12.54350765974511, 11.69420415438683, 12.254245094079453, 12.585568172943356, 12.475151959573655, 12.58532247612165, 12.58472863611536, 12.394762295429246, 12.577552806103277, 12.480285478633544, 12.506067901934994, 12.483214417063557, 12.582292580529336, -2.118281363980678, 9.671118441317523, 11.690524158917672, 12.15647542734203, 12.533301721397773, 12.585021178932509, 12.493611866605715, 11.942953167144333, 12.554404097853645, 11.241312196447442, 12.477208460479961, 12.385786149559516, 12.011853116942708, 12.540385497539605, 12.516333780605748, 12.508344049289972, 12.565903077154728, 12.513381440452305, 12.557043057018939, 12.57924954806046, 12.579003383204286, 12.38157177573587, 12.240889783704553, 12.580159587898859, 12.369502007126071, 12.581227568096105, 12.53625344459669, 12.572394587588025, 11.211968498874644, 12.543034423711651, 12.585508594282937, 12.579245548493184, 12.58587341651404, 12.192505007935493, 12.251932759150337, 12.006486527354618, 12.558816024771616, 12.403589404232175, 12.534559521483466, 10.384203599371235, 12.563765531825329, 12.528181775337472, 12.531378620952156, 10.228598753795454, 12.539907081215551, 12.490452485022812, 12.509896955745244, 12.234366574573157, 11.417645224921472, 12.183424809493685, 12.477519011987004, 12.55519278911892, 12.381537917696928, 11.033482533119487, 12.447587207830153, 12.585861853935237, 12.583971696733919, 12.585565460470868, 12.407046530197118, 12.493052735610126, 12.584879268754209, 12.50078512242822, 12.523610695425893, 12.52784654564936, 12.563812016157776, 12.57859039597151, 11.953689345995972, 12.040485785060572, 12.088555020500639, 12.357983423563043, 12.117687155856496, 12.579676767795942, 12.478382493032926, 12.493749107076477, 12.399020653855791, 12.332503212245378, 11.843126265537462, 12.497521901016176, 12.571031511658346, 12.459983579401838, 11.687138206103391, 12.096884427831979, 12.121225985747644, 12.480502912555634, 11.863150662877892, 9.061403067514844, 12.548953485441299, 12.229030843348552, 12.283601992351693, 11.548910927213958, 12.42743547320283]

# %%
# GDP
df_gdp_raw = pd.read_csv('data/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_2163564.csv')

# %%
df_gdp_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 65 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            131 non-null    float64
#  5   1961            132 non-null    float64
#  6   1962            135 non-null    float64
#  7   1963            135 non-null    float64
#  8   1964            135 non-null    float64
#  9   1965            144 non-null    float64
#  10  1966            148 non-null    float64
#  11  1967            152 non-null    float64
#  12  1968            156 non-null    float64
#  13  1969            156 non-null    float64
#  14  1970            167 non-null    float64
#  15  1971            168 non-null    float64
#  16  1972            168 non-null    float64
#  17  1973            168 non-null    float64
#  18  1974            169 non-null    float64
#  19  1975            172 non-null    float64
#  20  1976            173 non-null    float64
#  21  1977            176 non-null    float64
#  22  1978            175 non-null    float64
#  23  1979            176 non-null    float64
#  24  1980            187 non-null    float64
#  25  1981            190 non-null    float64
#  26  1982            191 non-null    float64
#  27  1983            192 non-null    float64
#  28  1984            193 non-null    float64
#  29  1985            195 non-null    float64
#  30  1986            197 non-null    float64
#  31  1987            201 non-null    float64
#  32  1988            206 non-null    float64
#  33  1989            206 non-null    float64
#  34  1990            223 non-null    float64
#  35  1991            222 non-null    float64
#  36  1992            223 non-null    float64
#  37  1993            228 non-null    float64
#  38  1994            230 non-null    float64
#  39  1995            236 non-null    float64
#  40  1996            236 non-null    float64
#  41  1997            236 non-null    float64
#  42  1998            238 non-null    float64
#  43  1999            239 non-null    float64
#  44  2000            245 non-null    float64
#  45  2001            245 non-null    float64
#  46  2002            250 non-null    float64
#  47  2003            250 non-null    float64
#  48  2004            251 non-null    float64
#  49  2005            251 non-null    float64
#  50  2006            252 non-null    float64
#  51  2007            252 non-null    float64
#  52  2008            251 non-null    float64
#  53  2009            251 non-null    float64
#  54  2010            252 non-null    float64
#  55  2011            254 non-null    float64
#  56  2012            253 non-null    float64
#  57  2013            253 non-null    float64
#  58  2014            253 non-null    float64
#  59  2015            252 non-null    float64
#  60  2016            251 non-null    float64
#  61  2017            251 non-null    float64
#  62  2018            249 non-null    float64
#  63  2019            230 non-null    float64
#  64  2020            0 non-null      float64
# dtypes: float64(61), object(4)
# memory usage: 134.2+ KB

# %%
df_gdp_raw.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
#            2011          2012          2013          2014          2015  \
# 0  2.549721e+09  2.534637e+09  2.701676e+09  2.765363e+09  2.919553e+09
# 1  1.780429e+10  2.000160e+10  2.056107e+10  2.048489e+10  1.990711e+10
# 2  1.117900e+11  1.280530e+11  1.367100e+11  1.457120e+11  1.161940e+11
# 3  1.289077e+10  1.231983e+10  1.277622e+10  1.322814e+10  1.138685e+10
# 4  3.629204e+09  3.188809e+09  3.193704e+09  3.271808e+09  2.789870e+09
#
#            2016          2017          2018          2019  2020
# 0  2.965922e+09  3.056425e+09           NaN           NaN   NaN
# 1  1.801775e+10  1.886995e+10  1.835388e+10  1.929110e+10   NaN
# 2  1.011240e+11  1.221240e+11  1.013530e+11  8.881570e+10   NaN
# 3  1.186120e+10  1.301969e+10  1.514702e+10  1.527918e+10   NaN
# 4  2.896679e+09  3.000181e+09  3.218316e+09  3.154058e+09   NaN
#
# [5 rows x 65 columns]

# %%
df_gdp = df_gdp_raw[['Country Name', '2019']]

# %%
df_gdp
# Out:
#      Country Name          2019
# 0           Aruba           NaN
# 1     Afghanistan  1.929110e+10
# 2          Angola  8.881570e+10
# 3         Albania  1.527918e+10
# 4         Andorra  3.154058e+09
# ..            ...           ...
# 259        Kosovo  7.926134e+09
# 260   Yemen, Rep.  2.258108e+10
# 261  South Africa  3.514320e+11
# 262        Zambia  2.330977e+10
# 263      Zimbabwe  2.144076e+10
#
# [264 rows x 2 columns]

# %%
df_gdp.dropna()
# Out:
#      Country Name          2019
# 1     Afghanistan  1.929110e+10
# 2          Angola  8.881570e+10
# 3         Albania  1.527918e+10
# 4         Andorra  3.154058e+09
# 5      Arab World  2.817410e+12
# ..            ...           ...
# 259        Kosovo  7.926134e+09
# 260   Yemen, Rep.  2.258108e+10
# 261  South Africa  3.514320e+11
# 262        Zambia  2.330977e+10
# 263      Zimbabwe  2.144076e+10
#
# [230 rows x 2 columns]

# %%
df_gdp.columns=['country', '2019']
df_gdp['2019'] = df_gdp['2019'].astype(str)
# Out:
# <ipython-input-37-78943a60e71e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp['2019'] = df_gdp['2019'].astype(str)

# %%
df_gdp.set_index('country', inplace=True)

# %%
vac_pop_gdp = pd.merge(vac_pop3, df_gdp, left_index=True, right_index=True, how='left')

# %%
vac_pop_gdp
# Out:
#              people_vaccinated_per_hundred  population            2019
# country
# Afghanistan                           0.31  39074280.0   19291104008.0
# Albania                               0.21   2877239.0   15279183290.0
# Andorra                               9.19     77287.0    3154057987.0
# Angola                                0.75  33032075.0   88815697793.0
# Anguilla                             38.89     15026.0             NaN
# ...                                    ...         ...             ...
# Uruguay                              25.12   3475842.0   56045912953.0
# Uzbekistan                            0.44  33551824.0   57921286440.0
# Venezuela                             0.88  28421581.0             NaN
# Vietnam                               0.06  97490013.0  261921000000.0
# Zimbabwe                              1.38  14899771.0   21440758800.0
#
# [153 rows x 3 columns]

# %%
#df_gdp.index.unique()

# %%
#set(df_gdp.index.unique()) - set(vac_pop3.index.unique())

# %%
vac_pop_gdp[vac_pop_gdp['2019'].isnull()]

# # Open the GDP CSV file and search each country name to find if the country name exist in the CSV file in different format. 

# Anguilla - not exist
# Bahamas - Bahamas, The
# Brunei - Brunei Darussalam
# Czech Republic (Czechia) - Czech Republic
# Egypt - Egypt, Arab Rep.

# Using ISO 3 digit code to merge data instead of the country name
# Out:
#                           people_vaccinated_per_hundred   population 2019
# country
# Anguilla                                          38.89      15026.0  NaN
# Bahamas                                            2.54     393893.0  NaN
# Brunei                                             0.53     438202.0  NaN
# Czech Republic (Czechia)                          13.13   10712481.0  NaN
# Egypt                                              0.15  102659126.0  NaN
# Faeroe Islands                                    17.15      48896.0  NaN
# Falkland Islands                                  74.79       3497.0  NaN
# Gambia                                             0.69    2427782.0  NaN
# Hong Kong                                          7.97    7507523.0  NaN
# Iran                                               0.15   84176929.0  NaN
# Kyrgyzstan                                         0.03    6542426.0  NaN
# Laos                                               0.56    7293542.0  NaN
# Macao                                              6.91     650846.0  NaN
# Montserrat                                        22.24       4993.0  NaN
# Russia                                             6.04  145945524.0  NaN
# Saint Helena                                      51.18       6080.0  NaN
# Saint Lucia                                       11.03     183774.0  NaN
# Slovakia                                          15.95    5460109.0  NaN
# South Korea                                        2.33   51276977.0  NaN
# Syria                                              0.01   17571053.0  NaN
# Taiwan                                             0.10   23824369.0  NaN
# Venezuela                                          0.88   28421581.0  NaN

# %%
df_vacc_raw = pd.read_csv('data/country_vaccinations.csv')
df_popu_raw = pd.read_csv('data/population_by_country_2020.csv')
df_gdp_raw = pd.read_csv('data/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_2163564.csv')

# %%
df_vacc_raw.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
df_popu_raw.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
df_gdp_raw.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
df_vacc = df_vacc_raw[['country','iso_code','people_vaccinated_per_hundred']]
df_popu = df_popu_raw[['Country (or dependency)','Population (2020)']]
df_gdp = df_gdp_raw[['Country Name','Country Code','2019']]

# %%
df_vacc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11364 entries, 0 to 11363
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        11364 non-null  object
#  1   iso_code                       11364 non-null  object
#  2   people_vaccinated_per_hundred  6091 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 266.5+ KB

# %%
df_vacc
# Out:
#            country iso_code  people_vaccinated_per_hundred
# 0      Afghanistan      AFG                           0.00
# 1      Afghanistan      AFG                            NaN
# 2      Afghanistan      AFG                            NaN
# 3      Afghanistan      AFG                            NaN
# 4      Afghanistan      AFG                            NaN
# ...            ...      ...                            ...
# 11359     Zimbabwe      ZWE                           1.12
# 11360     Zimbabwe      ZWE                           1.20
# 11361     Zimbabwe      ZWE                           1.30
# 11362     Zimbabwe      ZWE                           1.31
# 11363     Zimbabwe      ZWE                           1.38
#
# [11364 rows x 3 columns]

# %%
vacc_max_country = df_vacc.groupby('country').max()

# %%
vacc_max_country.shape
# Out:
# (176, 2)

# %%
vacc_max_country
# Out:
#              iso_code  people_vaccinated_per_hundred
# country
# Afghanistan       AFG                           0.31
# Albania           ALB                           0.21
# Algeria           DZA                            NaN
# Andorra           AND                           9.19
# Angola            AGO                           0.75
# ...               ...                            ...
# Uzbekistan        UZB                           0.44
# Venezuela         VEN                           0.88
# Vietnam           VNM                           0.06
# Wales        OWID_WLS                          50.36
# Zimbabwe          ZWE                           1.38
#
# [176 rows x 2 columns]

# %%
vacc_max_country['people_vaccinated_per_hundred'].isnull().sum()
# Out:
# 9

# %%
vacc_max_country.dropna()
# Out:
#              iso_code  people_vaccinated_per_hundred
# country
# Afghanistan       AFG                           0.31
# Albania           ALB                           0.21
# Andorra           AND                           9.19
# Angola            AGO                           0.75
# Anguilla          AIA                          38.89
# ...               ...                            ...
# Uzbekistan        UZB                           0.44
# Venezuela         VEN                           0.88
# Vietnam           VNM                           0.06
# Wales        OWID_WLS                          50.36
# Zimbabwe          ZWE                           1.38
#
# [167 rows x 2 columns]

# %%
vacc_max_country['iso_code_n'] = vacc_max_country['iso_code'].str.findall(pat='[a-zA-Z]')

# %%
vacc_max_country
# Out:
#              iso_code  people_vaccinated_per_hundred             iso_code_n
# country
# Afghanistan       AFG                           0.31              [A, F, G]
# Albania           ALB                           0.21              [A, L, B]
# Algeria           DZA                            NaN              [D, Z, A]
# Andorra           AND                           9.19              [A, N, D]
# Angola            AGO                           0.75              [A, G, O]
# ...               ...                            ...                    ...
# Uzbekistan        UZB                           0.44              [U, Z, B]
# Venezuela         VEN                           0.88              [V, E, N]
# Vietnam           VNM                           0.06              [V, N, M]
# Wales        OWID_WLS                          50.36  [O, W, I, D, W, L, S]
# Zimbabwe          ZWE                           1.38              [Z, W, E]
#
# [176 rows x 3 columns]

# %%
vacc_max_country['n_iso_code'] = vacc_max_country['iso_code_n'].str.len()

# %%
vacc_max_country.loc[vacc_max_country.n_iso_code > 3]
# Out:
#                   iso_code  people_vaccinated_per_hundred  \
# country
# England           OWID_ENG                          48.16
# Kosovo            OWID_KOS                           0.13
# Northern Cyprus   OWID_CYN                          14.10
# Northern Ireland  OWID_NIR                          43.64
# Scotland          OWID_SCT                          48.85
# Wales             OWID_WLS                          50.36
#
#                              iso_code_n  n_iso_code
# country
# England           [O, W, I, D, E, N, G]           7
# Kosovo            [O, W, I, D, K, O, S]           7
# Northern Cyprus   [O, W, I, D, C, Y, N]           7
# Northern Ireland  [O, W, I, D, N, I, R]           7
# Scotland          [O, W, I, D, S, C, T]           7
# Wales             [O, W, I, D, W, L, S]           7
